# %% [markdown]
# ## **Resources**
#
# [Hussain_Nasser_webTransport](https://www.youtube.com/watch?v=h9LYokF5K0k) : Best to understand `webTransport` in depth.
#
# [Hussain_Nasser_webTransport](https://www.youtube.com/watch?v=SEF8VBYlLik)
#
# [WebTransport_Rust](https://www.youtube.com/watch?v=dztIToTf8Yc)
#
# [webSocket_Vs_webTransport](https://www.youtube.com/watch?v=ReV31oGX6oo)

# %% [markdown]
# ## **Intro to webTransport**
